# %%
import requests
import pandas as pd
import numpy as np
import random

# !pip install geopy
from geopy.geocoders import Nominatim
from pandas.io.json import json_normalize

# !pip install folium
import folium

print('done')
# Out:
# ...
# done

# %%
CLIENT_ID = 'PUWDRFVIHIBYUW4VZ4NJZMEHLOL1UMCUWQ0APEWLCIF14LNG'
CLIENT_SECRET = 'LWGA5M2DOMY2CYPQT1UJVNLWTMWFKMKHGETF1QVSCJ1T5R0A'
VERSION = '20201122'
LIMIT = 100
radius = 500

# %%
address = 'Petaling Jaya, Selangor, MY'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 3.13964625 101.58963737989805

# %%
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude, 
    longitude, 
    radius, 
    LIMIT)

# %%
import json
result = requests.get(url).json()
result_data = json.load(result)
result_data1 = result_data['features']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-81-9bd431e99beb> in <module>
#       1 import json
#       2 result = requests.get(url).json()
# ----> 3 result_data = json.load(result)
#       4 result_data1 = result_data['features']
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#
# AttributeError: 'dict' object has no attribute 'read'

# %%
column_name = ['latitude', 'logitude']
data = pd.DataFrame(columns=column_name)
data
# Out:
# Empty DataFrame
# Columns: [latitude, logitude]
# Index: []

# %%
for place in data:
    data_lation = place['location']
    data_lat = data_lation[1]
    data_lng = data_lation[0]
    shop_name = shop_name.append({'latitude': data_lat, 'logitude': data_lng}, ignore_index=True)
shop_name.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-78-4f7b017aad89> in <module>
#       1 for place in data:
# ----> 2     data_lation = place['location']
#       3     data_lat = data_lation[1]
#       4     data_lng = data_lation[0]
#       5     shop_name = shop_name.append({'latitude': data_lat, 'logitude': data_lng}, ignore_index=True)
#
# TypeError: string indices must be integers

# %%
shop_map = folium.Map(location=[latitude, longitude], zoom_start=13)

for lat, lng, label in zip('venue', 'distance', 'postalCode'):
    folium.CircleMarker([lat, lng], radius=5, color='blue', popup=label, fill=True, fill_color='blue', fill_opacity=0.6).add_to(shop_map)
shop_map
